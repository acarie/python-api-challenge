# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

units = "metric"

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 573

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vysokaya gora
# Processing Record 2 of Set 1 | saipan
# Processing Record 3 of Set 1 | pelabuhan klang
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | utrik
# Processing Record 6 of Set 1 | bahia blanca
# Processing Record 7 of Set 1 | tolanaro
# Processing Record 8 of Set 1 | nizhneangarsk
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | yarmouth
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | margaret river
# Processing Record 13 of Set 1 | atafu village
# Processing Record 14 of Set 1 | olonkinbyen
# Processing Record 15 of Set 1 | aasiaat
# Processing Record 16 of Set 1 | roswell
# Processing Record 17 of Set 1 | callao
# Processing Record 18 of Set 1 | grytviken
# Processing Record 19 of Set 1 | itaituba
# Processing Record 20 of Set 1 | blackmans bay
# Processing Record 21 of Set 1 | tinajo
# Processing Record 22 of Set 1 | edinburgh of the seven seas
# Processing Record 23 of Set 1 | zouerate
# Processing Record 24 of Set 1 | ola
# Processing Record 25 of Set 1 | mejit
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | san patricio
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | keflavik
# Processing Record 30 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 31 of Set 1 | enewetak
# Processing Record 32 of Set 1 | whitehorse
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | bandon
# Processing Record 35 of Set 1 | puerto natales
# Processing Record 36 of Set 1 | lazaro cardenas
# Processing Record 37 of Set 1 | wad rawah
# Processing Record 38 of Set 1 | hamilton
# Processing Record 39 of Set 1 | kodiak
# Processing Record 40 of Set 1 | longyearbyen
# Processing Record 41 of Set 1 | port mathurin
# Processing Record 42 of Set 1 | harrison
# Processing Record 43 of Set 1 | urzhum
# Processing Record 44 of Set 1 | aykhal
# Processing Record 45 of Set 1 | ilulissat
# Processing Record 46 of Set 1 | port elizabeth
# Processing Record 47 of Set 1 | rongelap
# Processing Record 48 of Set 1 | lompoc
# Processing Record 49 of Set 1 | leppavirta
# Processing Record 50 of Set 1 | lihue
# Processing Record 0 of Set 2 | sarakhs
# Processing Record 1 of Set 2 | jawad
# Processing Record 2 of Set 2 | san jose village
# City not found. Skipping...
# Processing Record 3 of Set 2 | namibe
# Processing Record 4 of Set 2 | ghanzi
# Processing Record 5 of Set 2 | saldanha
# Processing Record 6 of Set 2 | mata-utu
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | san antonio de pale
# Processing Record 9 of Set 2 | huarmey
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | tsiombe
# Processing Record 13 of Set 2 | kismayo
# Processing Record 14 of Set 2 | nar'yan-mar
# Processing Record 15 of Set 2 | alice springs
# Processing Record 16 of Set 2 | carnarvon
# Processing Record 17 of Set 2 | shiyan
# Processing Record 18 of Set 2 | beloyarskiy
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | greymouth
# Processing Record 21 of Set 2 | vorgashor
# Processing Record 22 of Set 2 | kapuskasing
# Processing Record 23 of Set 2 | boguchany
# Processing Record 24 of Set 2 | carutapera
# Processing Record 25 of Set 2 | tibagi
# Processing Record 26 of Set 2 | margate
# Processing Record 27 of Set 2 | waitangi
# Processing Record 28 of Set 2 | hermanus
# Processing Record 29 of Set 2 | kingston
# Processing Record 30 of Set 2 | thompson
# Processing Record 31 of Set 2 | wailua homesteads
# Processing Record 32 of Set 2 | hawaiian paradise park
# Processing Record 33 of Set 2 | quincy
# Processing Record 34 of Set 2 | hanceville
# Processing Record 35 of Set 2 | ilhabela
# Processing Record 36 of Set 2 | punta arenas
# Processing Record 37 of Set 2 | khandyga
# Processing Record 38 of Set 2 | lincheng
# Processing Record 39 of Set 2 | mpika
# Processing Record 40 of Set 2 | college
# Processing Record 41 of Set 2 | adamstown
# Processing Record 42 of Set 2 | udachny
# Processing Record 43 of Set 2 | gadzhiyevo
# Processing Record 44 of Set 2 | cafayate
# Processing Record 45 of Set 2 | murun-kuren
# Processing Record 46 of Set 2 | koundara
# Processing Record 47 of Set 2 | aykol
# City not found. Skipping...
# Processing Record 48 of Set 2 | belmonte
# Processing Record 49 of Set 2 | albertina
# Processing Record 0 of Set 3 | west island
# Processing Record 1 of Set 3 | xilin hot
# Processing Record 2 of Set 3 | ankang
# Processing Record 3 of Set 3 | lebu
# Processing Record 4 of Set 3 | bilibino
# Processing Record 5 of Set 3 | fort st. john
# Processing Record 6 of Set 3 | prince rupert
# Processing Record 7 of Set 3 | usinsk
# Processing Record 8 of Set 3 | katsuura
# Processing Record 9 of Set 3 | stanley
# Processing Record 10 of Set 3 | brokopondo
# Processing Record 11 of Set 3 | alaghsas
# Processing Record 12 of Set 3 | tocopilla
# Processing Record 13 of Set 3 | kone
# Processing Record 14 of Set 3 | vilyuchinsk
# Processing Record 15 of Set 3 | itoman
# Processing Record 16 of Set 3 | luderitz
# Processing Record 17 of Set 3 | almus
# Processing Record 18 of Set 3 | usogorsk
# Processing Record 19 of Set 3 | concepcion del oro
# Processing Record 20 of Set 3 | alofi
# Processing Record 21 of Set 3 | tiksi
# Processing Record 22 of Set 3 | vernon
# Processing Record 23 of Set 3 | hilo
# Processing Record 24 of Set 3 | remire-montjoly
# Processing Record 25 of Set 3 | kiunga
# Processing Record 26 of Set 3 | el calafate
# Processing Record 27 of Set 3 | richards bay
# Processing Record 28 of Set 3 | bardai
# Processing Record 29 of Set 3 | qaqortoq
# Processing Record 30 of Set 3 | luganville
# Processing Record 31 of Set 3 | papatowai
# Processing Record 32 of Set 3 | tidjikja
# Processing Record 33 of Set 3 | melekeok village
# Processing Record 34 of Set 3 | canchungo
# Processing Record 35 of Set 3 | morwell
# Processing Record 36 of Set 3 | santa terezinha
# Processing Record 37 of Set 3 | ust-nera
# Processing Record 38 of Set 3 | makoua
# Processing Record 39 of Set 3 | fale old settlement
# Processing Record 40 of Set 3 | bandarbeyla
# Processing Record 41 of Set 3 | airdrie
# Processing Record 42 of Set 3 | nova sintra
# Processing Record 43 of Set 3 | sao gabriel da cachoeira
# Processing Record 44 of Set 3 | thunder bay
# Processing Record 45 of Set 3 | ghadamis
# Processing Record 46 of Set 3 | cangucu
# Processing Record 47 of Set 3 | ca mau
# Processing Record 48 of Set 3 | port lincoln
# Processing Record 49 of Set 3 | klyuchi
# Processing Record 0 of Set 4 | rio grande
# Processing Record 1 of Set 4 | iqaluit
# Processing Record 2 of Set 4 | kalamb
# Processing Record 3 of Set 4 | georgetown
# Processing Record 4 of Set 4 | touros
# Processing Record 5 of Set 4 | carupano
# Processing Record 6 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 7 of Set 4 | fonadhoo
# City not found. Skipping...
# Processing Record 8 of Set 4 | codrington
# Processing Record 9 of Set 4 | kerikeri
# Processing Record 10 of Set 4 | dolores
# Processing Record 11 of Set 4 | khadan khak
# Processing Record 12 of Set 4 | cabo san lucas
# Processing Record 13 of Set 4 | howrah
# Processing Record 14 of Set 4 | monrovia
# Processing Record 15 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 16 of Set 4 | saynshand
# Processing Record 17 of Set 4 | nemuro
# Processing Record 18 of Set 4 | kihoku-cho
# Processing Record 19 of Set 4 | san matias
# Processing Record 20 of Set 4 | hadibu
# Processing Record 21 of Set 4 | narvik
# Processing Record 22 of Set 4 | gimbi
# Processing Record 23 of Set 4 | kimbe
# Processing Record 24 of Set 4 | minas de marcona
# Processing Record 25 of Set 4 | akureyri
# Processing Record 26 of Set 4 | purpe
# Processing Record 27 of Set 4 | taupo
# Processing Record 28 of Set 4 | tinogasta
# Processing Record 29 of Set 4 | isafjordur
# Processing Record 30 of Set 4 | taguatinga
# Processing Record 31 of Set 4 | piti village
# Processing Record 32 of Set 4 | janeng
# Processing Record 33 of Set 4 | international falls
# Processing Record 34 of Set 4 | iskateley
# Processing Record 35 of Set 4 | sergeyevka
# Processing Record 36 of Set 4 | argo
# Processing Record 37 of Set 4 | ribeira grande
# Processing Record 38 of Set 4 | camrose
# Processing Record 39 of Set 4 | polyarnyy
# Processing Record 40 of Set 4 | port alfred
# Processing Record 41 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 42 of Set 4 | vila velha
# Processing Record 43 of Set 4 | okhotsk
# Processing Record 44 of Set 4 | san fernando de apure
# Processing Record 45 of Set 4 | kourou
# Processing Record 46 of Set 4 | banamba
# Processing Record 47 of Set 4 | anna regina
# Processing Record 48 of Set 4 | choibalsan
# Processing Record 49 of Set 4 | papao
# Processing Record 0 of Set 5 | miri
# Processing Record 1 of Set 5 | malvan
# Processing Record 2 of Set 5 | kristiansund
# Processing Record 3 of Set 5 | cill airne
# Processing Record 4 of Set 5 | haiku-pauwela
# Processing Record 5 of Set 5 | dryden
# Processing Record 6 of Set 5 | lethem
# Processing Record 7 of Set 5 | naze
# Processing Record 8 of Set 5 | talnakh
# Processing Record 9 of Set 5 | sayat
# Processing Record 10 of Set 5 | cidreira
# Processing Record 11 of Set 5 | esperanza
# Processing Record 12 of Set 5 | puerto maldonado
# Processing Record 13 of Set 5 | wuchang
# Processing Record 14 of Set 5 | kyabram
# Processing Record 15 of Set 5 | rizokarpaso
# Processing Record 16 of Set 5 | nema
# Processing Record 17 of Set 5 | pirallahi
# Processing Record 18 of Set 5 | saint-philippe
# Processing Record 19 of Set 5 | chonchi
# Processing Record 20 of Set 5 | zavodskoy
# Processing Record 21 of Set 5 | bata
# Processing Record 22 of Set 5 | severo-yeniseyskiy
# Processing Record 23 of Set 5 | tazovsky
# Processing Record 24 of Set 5 | koster
# Processing Record 25 of Set 5 | las vegas, santa barbara
# Processing Record 26 of Set 5 | hami
# Processing Record 27 of Set 5 | manakara
# Processing Record 28 of Set 5 | amper
# Processing Record 29 of Set 5 | holualoa
# Processing Record 30 of Set 5 | fortuna
# Processing Record 31 of Set 5 | eraan
# Processing Record 32 of Set 5 | insar
# Processing Record 33 of Set 5 | antigonish
# Processing Record 34 of Set 5 | mount gambier
# Processing Record 35 of Set 5 | banda aceh
# Processing Record 36 of Set 5 | feodosiya
# Processing Record 37 of Set 5 | nasir
# Processing Record 38 of Set 5 | adrar
# Processing Record 39 of Set 5 | porto velho
# Processing Record 40 of Set 5 | awjilah
# Processing Record 41 of Set 5 | mukah
# City not found. Skipping...
# Processing Record 42 of Set 5 | chos malal
# Processing Record 43 of Set 5 | betio village
# Processing Record 44 of Set 5 | shenjiamen
# Processing Record 45 of Set 5 | ouargaye
# Processing Record 46 of Set 5 | yaren
# Processing Record 47 of Set 5 | nyurba
# Processing Record 48 of Set 5 | north myrtle beach
# Processing Record 49 of Set 5 | anadyr
# Processing Record 0 of Set 6 | palmas
# Processing Record 1 of Set 6 | buka
# Processing Record 2 of Set 6 | torit
# Processing Record 3 of Set 6 | zaterechnyy
# Processing Record 4 of Set 6 | burgos
# Processing Record 5 of Set 6 | brumunddal
# Processing Record 6 of Set 6 | kasane
# Processing Record 7 of Set 6 | masterton
# Processing Record 8 of Set 6 | bodo
# Processing Record 9 of Set 6 | maintirano
# Processing Record 10 of Set 6 | petukhovo
# Processing Record 11 of Set 6 | turpan
# Processing Record 12 of Set 6 | portland
# Processing Record 13 of Set 6 | maun
# Processing Record 14 of Set 6 | bosobolo
# Processing Record 15 of Set 6 | filadelfia
# Processing Record 16 of Set 6 | jutai
# Processing Record 17 of Set 6 | hauterive
# Processing Record 18 of Set 6 | arkhangel'sk
# Processing Record 19 of Set 6 | muli
# Processing Record 20 of Set 6 | invercargill
# Processing Record 21 of Set 6 | guiuan
# Processing Record 22 of Set 6 | imbituba
# Processing Record 23 of Set 6 | meulaboh
# Processing Record 24 of Set 6 | baligang
# Processing Record 25 of Set 6 | lages
# Processing Record 26 of Set 6 | badger
# Processing Record 27 of Set 6 | pochinki
# Processing Record 28 of Set 6 | qamdo
# Processing Record 29 of Set 6 | jacarau
# Processing Record 30 of Set 6 | saksaul'skiy
# City not found. Skipping...
# Processing Record 31 of Set 6 | san leone mose
# City not found. Skipping...
# Processing Record 32 of Set 6 | bel ombre
# Processing Record 33 of Set 6 | nouadhibou
# Processing Record 34 of Set 6 | hithadhoo
# Processing Record 35 of Set 6 | chiavenna
# Processing Record 36 of Set 6 | saint-jean-de-monts
# Processing Record 37 of Set 6 | onega
# Processing Record 38 of Set 6 | dogondoutchi
# Processing Record 39 of Set 6 | newman
# Processing Record 40 of Set 6 | hayma'
# City not found. Skipping...
# Processing Record 41 of Set 6 | dunda
# Processing Record 42 of Set 6 | happy valley-goose bay
# Processing Record 43 of Set 6 | salalah
# Processing Record 44 of Set 6 | malazgirt
# Processing Record 45 of Set 6 | barakani
# Processing Record 46 of Set 6 | santana
# Processing Record 47 of Set 6 | sisimiut
# Processing Record 48 of Set 6 | mugia
# Processing Record 49 of Set 6 | rocha
# Processing Record 0 of Set 7 | kiffa
# Processing Record 1 of Set 7 | okha
# Processing Record 2 of Set 7 | mingshui
# Processing Record 3 of Set 7 | laojunmiao
# Processing Record 4 of Set 7 | saint-francois
# Processing Record 5 of Set 7 | birao
# Processing Record 6 of Set 7 | st. john's
# Processing Record 7 of Set 7 | athens
# Processing Record 8 of Set 7 | muang phonsavan
# Processing Record 9 of Set 7 | san andres
# Processing Record 10 of Set 7 | kalkaman
# Processing Record 11 of Set 7 | umm kaddadah
# Processing Record 12 of Set 7 | veinticinco de mayo
# Processing Record 13 of Set 7 | hovd
# Processing Record 14 of Set 7 | neryungri
# Processing Record 15 of Set 7 | edirne
# Processing Record 16 of Set 7 | robbah
# Processing Record 17 of Set 7 | novoagansk
# Processing Record 18 of Set 7 | westport
# Processing Record 19 of Set 7 | salamanca
# Processing Record 20 of Set 7 | arno
# Processing Record 21 of Set 7 | illizi
# Processing Record 22 of Set 7 | ivrea
# Processing Record 23 of Set 7 | mitsamiouli
# Processing Record 24 of Set 7 | stebnyk
# Processing Record 25 of Set 7 | kayangel
# Processing Record 26 of Set 7 | harstad
# Processing Record 27 of Set 7 | preston
# Processing Record 28 of Set 7 | lauro de freitas
# Processing Record 29 of Set 7 | prado
# Processing Record 30 of Set 7 | afaahiti
# Processing Record 31 of Set 7 | bargara
# City not found. Skipping...
# Processing Record 32 of Set 7 | puerto deseado
# Processing Record 33 of Set 7 | fisterra
# Processing Record 34 of Set 7 | governor's harbour
# City not found. Skipping...
# Processing Record 35 of Set 7 | cockburn town
# Processing Record 36 of Set 7 | brandywine
# Processing Record 37 of Set 7 | daru
# Processing Record 38 of Set 7 | vila franca do campo
# Processing Record 39 of Set 7 | koungou
# Processing Record 40 of Set 7 | al jawf
# Processing Record 41 of Set 7 | christchurch
# Processing Record 42 of Set 7 | muynoq
# Processing Record 43 of Set 7 | luchegorsk
# Processing Record 44 of Set 7 | loddekopinge
# Processing Record 45 of Set 7 | kolonia
# Processing Record 46 of Set 7 | glace bay
# Processing Record 47 of Set 7 | tura
# Processing Record 48 of Set 7 | ta`u
# Processing Record 49 of Set 7 | greenville
# Processing Record 0 of Set 8 | mar del plata
# Processing Record 1 of Set 8 | tenango del aire
# Processing Record 2 of Set 8 | puerto san carlos
# City not found. Skipping...
# Processing Record 3 of Set 8 | susuman
# Processing Record 4 of Set 8 | yuzhno-kurilsk
# Processing Record 5 of Set 8 | puerto aysen
# Processing Record 6 of Set 8 | galle
# Processing Record 7 of Set 8 | faya-largeau
# Processing Record 8 of Set 8 | yabelo
# Processing Record 9 of Set 8 | ugoofaaru
# Processing Record 10 of Set 8 | constantia
# Processing Record 11 of Set 8 | bakchar
# Processing Record 12 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 13 of Set 8 | iten
# City not found. Skipping...
# Processing Record 14 of Set 8 | opuwo
# Processing Record 15 of Set 8 | leo
# Processing Record 16 of Set 8 | murud
# Processing Record 17 of Set 8 | sur
# Processing Record 18 of Set 8 | bamboo flat
# Processing Record 19 of Set 8 | wewak
# Processing Record 20 of Set 8 | kem'
# Processing Record 21 of Set 8 | labrador city
# Processing Record 22 of Set 8 | cumra
# Processing Record 23 of Set 8 | al mijlad
# Processing Record 24 of Set 8 | tuba city
# Processing Record 25 of Set 8 | ust'-uda
# Processing Record 26 of Set 8 | colonia
# Processing Record 27 of Set 8 | gounou gaya
# Processing Record 28 of Set 8 | elmendorf air force base
# City not found. Skipping...
# Processing Record 29 of Set 8 | pacific grove
# Processing Record 30 of Set 8 | crane
# Processing Record 31 of Set 8 | holmsund
# Processing Record 32 of Set 8 | qalat
# Processing Record 33 of Set 8 | megarine
# Processing Record 34 of Set 8 | qandala
# Processing Record 35 of Set 8 | chulym
# Processing Record 36 of Set 8 | tromso
# Processing Record 37 of Set 8 | berdigestyakh
# Processing Record 38 of Set 8 | midvagur
# Processing Record 39 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 40 of Set 8 | tamanrasset
# Processing Record 41 of Set 8 | vingt cinq
# City not found. Skipping...
# Processing Record 42 of Set 8 | monte buey
# Processing Record 43 of Set 8 | alexandria
# Processing Record 44 of Set 8 | bodaybo
# Processing Record 45 of Set 8 | uruacu
# Processing Record 46 of Set 8 | quba
# Processing Record 47 of Set 8 | kapa'a
# Processing Record 48 of Set 8 | fort bragg
# Processing Record 49 of Set 8 | trinity beach
# Processing Record 0 of Set 9 | ar raqqah
# Processing Record 1 of Set 9 | el granada
# Processing Record 2 of Set 9 | akaltara
# Processing Record 3 of Set 9 | brookings
# Processing Record 4 of Set 9 | basco
# Processing Record 5 of Set 9 | port isabel
# Processing Record 6 of Set 9 | nishinoomote
# Processing Record 7 of Set 9 | weno
# Processing Record 8 of Set 9 | andalgala
# Processing Record 9 of Set 9 | tondano
# Processing Record 10 of Set 9 | strezhevoy
# Processing Record 11 of Set 9 | yerofey pavlovich
# Processing Record 12 of Set 9 | vorkuta
# Processing Record 13 of Set 9 | brigantine
# Processing Record 14 of Set 9 | east london
# Processing Record 15 of Set 9 | selizharovo
# Processing Record 16 of Set 9 | lourdes
# Processing Record 17 of Set 9 | otra banda
# Processing Record 18 of Set 9 | aroma
# Processing Record 19 of Set 9 | belyy yar
# Processing Record 20 of Set 9 | pervomayskiy
# Processing Record 21 of Set 9 | natal
# Processing Record 22 of Set 9 | daday
# Processing Record 23 of Set 9 | anabar
# City not found. Skipping...
# Processing Record 24 of Set 9 | kardla
# Processing Record 25 of Set 9 | kittila
# Processing Record 26 of Set 9 | salekhard
# Processing Record 27 of Set 9 | tabou
# Processing Record 28 of Set 9 | kingscliff
# Processing Record 29 of Set 9 | tarrafal de sao nicolau
# Processing Record 30 of Set 9 | tamazulapam villa del progreso
# Processing Record 31 of Set 9 | sitka
# Processing Record 32 of Set 9 | inhambane
# Processing Record 33 of Set 9 | mana
# Processing Record 34 of Set 9 | senador pompeu
# Processing Record 35 of Set 9 | khawr fakkan
# Processing Record 36 of Set 9 | jayapura
# Processing Record 37 of Set 9 | andreapol'
# Processing Record 38 of Set 9 | ceeldheer
# Processing Record 39 of Set 9 | fallon
# Processing Record 40 of Set 9 | manaure
# Processing Record 41 of Set 9 | ouallam
# Processing Record 42 of Set 9 | tambura
# Processing Record 43 of Set 9 | turan
# Processing Record 44 of Set 9 | pyt-yakh
# Processing Record 45 of Set 9 | ma'an
# Processing Record 46 of Set 9 | tofol
# Processing Record 47 of Set 9 | launceston
# Processing Record 48 of Set 9 | puerto armuelles
# Processing Record 49 of Set 9 | puerto real
# Processing Record 0 of Set 10 | peterborough
# Processing Record 1 of Set 10 | folkestone
# Processing Record 2 of Set 10 | camapua
# Processing Record 3 of Set 10 | deniliquin
# Processing Record 4 of Set 10 | sutherlin
# Processing Record 5 of Set 10 | lerwick
# Processing Record 6 of Set 10 | saint-joseph
# Processing Record 7 of Set 10 | uturoa
# Processing Record 8 of Set 10 | tosontsengel
# Processing Record 9 of Set 10 | walvis bay
# Processing Record 10 of Set 10 | korla
# Processing Record 11 of Set 10 | ithaca
# Processing Record 12 of Set 10 | egilsstadir
# Processing Record 13 of Set 10 | santa marta
# Processing Record 14 of Set 10 | tver
# Processing Record 15 of Set 10 | chibougamau
# Processing Record 16 of Set 10 | barreiras
# Processing Record 17 of Set 10 | malango
# Processing Record 18 of Set 10 | nambucca heads
# Processing Record 19 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 20 of Set 10 | saratamata
# City not found. Skipping...
# Processing Record 21 of Set 10 | patong
# Processing Record 22 of Set 10 | bambous
# Processing Record 23 of Set 10 | nelson
# Processing Record 24 of Set 10 | queenstown
# Processing Record 25 of Set 10 | novyy urengoy
# Processing Record 26 of Set 10 | port augusta
# Processing Record 27 of Set 10 | acapulco de juarez
# Processing Record 28 of Set 10 | sungai penuh
# Processing Record 29 of Set 10 | sundsvall
# Processing Record 30 of Set 10 | broken hill
# Processing Record 31 of Set 10 | siracusa
# Processing Record 32 of Set 10 | cooper's town
# Processing Record 33 of Set 10 | mil'kovo
# Processing Record 34 of Set 10 | sotik post
# Processing Record 35 of Set 10 | tarawa
# Processing Record 36 of Set 10 | humaita
# Processing Record 37 of Set 10 | ouellah
# City not found. Skipping...
# Processing Record 38 of Set 10 | along
# Processing Record 39 of Set 10 | ryotsu-minato
# Processing Record 40 of Set 10 | leava
# Processing Record 41 of Set 10 | motygino
# Processing Record 42 of Set 10 | bikenibeu village
# Processing Record 43 of Set 10 | stornoway
# Processing Record 44 of Set 10 | cole harbour
# Processing Record 45 of Set 10 | hailar
# Processing Record 46 of Set 10 | xining
# Processing Record 47 of Set 10 | savave village
# City not found. Skipping...
# Processing Record 48 of Set 10 | aleksandrovskoye
# Processing Record 49 of Set 10 | selfoss
# Processing Record 0 of Set 11 | swedru
# Processing Record 1 of Set 11 | skutskar
# City not found. Skipping...
# Processing Record 2 of Set 11 | bairnsdale
# Processing Record 3 of Set 11 | celestun
# Processing Record 4 of Set 11 | al ghayzah
# Processing Record 5 of Set 11 | santa ana
# Processing Record 6 of Set 11 | yingkou
# Processing Record 7 of Set 11 | tokar
# Processing Record 8 of Set 11 | genhe
# Processing Record 9 of Set 11 | dampit
# Processing Record 10 of Set 11 | bhamo
# Processing Record 11 of Set 11 | swiebodzin
# Processing Record 12 of Set 11 | toga village
# City not found. Skipping...
# Processing Record 13 of Set 11 | ardestan
# Processing Record 14 of Set 11 | altamira
# Processing Record 15 of Set 11 | middelburg
# Processing Record 16 of Set 11 | tegueste
# Processing Record 17 of Set 11 | tanout
# Processing Record 18 of Set 11 | fada
# Processing Record 19 of Set 11 | murzuq
# Processing Record 20 of Set 11 | arauco
# Processing Record 21 of Set 11 | amga
# Processing Record 22 of Set 11 | sidhi
# Processing Record 23 of Set 11 | lamar
# Processing Record 24 of Set 11 | kanggye
# Processing Record 25 of Set 11 | haworth
# Processing Record 26 of Set 11 | lodja
# Processing Record 27 of Set 11 | morondava
# Processing Record 28 of Set 11 | concepcion del uruguay
# Processing Record 29 of Set 11 | villa gesell
# Processing Record 30 of Set 11 | nagqu
# Processing Record 31 of Set 11 | ko pha ngan
# Processing Record 32 of Set 11 | gap
# Processing Record 33 of Set 11 | umatac village
# City not found. Skipping...
# Processing Record 34 of Set 11 | yarkovo
# Processing Record 35 of Set 11 | port saint john's
# Processing Record 36 of Set 11 | talara
# Processing Record 37 of Set 11 | puyang
# Processing Record 38 of Set 11 | dudinka
# Processing Record 39 of Set 11 | korotchaevo
# City not found. Skipping...
# Processing Record 40 of Set 11 | poronaysk
# Processing Record 41 of Set 11 | tamiahua
# Processing Record 42 of Set 11 | nuriootpa
# Processing Record 43 of Set 11 | naryn
# Processing Record 44 of Set 11 | karratha
# Processing Record 45 of Set 11 | al 'alamayn
# City not found. Skipping...
# Processing Record 46 of Set 11 | shimoda
# Processing Record 47 of Set 11 | preobrazheniye
# Processing Record 48 of Set 11 | weyburn
# Processing Record 49 of Set 11 | altamont
# Processing Record 0 of Set 12 | kruisfontein
# Processing Record 1 of Set 12 | camayenne
# Processing Record 2 of Set 12 | kuala belait
# Processing Record 3 of Set 12 | kalmunai
# Processing Record 4 of Set 12 | san andros
# City not found. Skipping...
# Processing Record 5 of Set 12 | zakynthos
# Processing Record 6 of Set 12 | vadso
# Processing Record 7 of Set 12 | al bardiyah
# Processing Record 8 of Set 12 | parry sound
# Processing Record 9 of Set 12 | alo
# Processing Record 10 of Set 12 | nguigmi
# Processing Record 11 of Set 12 | amta
# Processing Record 12 of Set 12 | kotlas
# Processing Record 13 of Set 12 | yavatmal
# Processing Record 14 of Set 12 | tazacorte
# Processing Record 15 of Set 12 | bontoc
# Processing Record 16 of Set 12 | sonsorol village
# City not found. Skipping...
# Processing Record 17 of Set 12 | tralee
# Processing Record 18 of Set 12 | hue
# Processing Record 19 of Set 12 | pisco
# Processing Record 20 of Set 12 | singaraja
# Processing Record 21 of Set 12 | anjiang
# Processing Record 22 of Set 12 | zapata
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          543
# Lat           543
# Lng           543
# Max Temp      543
# Humidity      543
# Cloudiness    543
# Wind Speed    543
# Country       543
# Date          543
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    vysokaya gora  55.9128   49.3017     10.10        90          65
# 1           saipan  15.1355  145.7010     27.39        89          40
# 2  pelabuhan klang   3.0000  101.4000     28.21        84         100
# 3           bethel  41.3712  -73.4140     28.45        65          40
# 4            utrik  11.2278  169.8474     28.27        78          14
#
#    Wind Speed Country        Date
# 0        5.55      RU  1693164541
# 1        3.09      MP  1693164541
# 2        1.59      MY  1693164541
# 3        3.60      US  1693164541
# 4        8.62      MH  1693164541

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          vysokaya gora  55.9128   49.3017     10.10        90          65
# 1                 saipan  15.1355  145.7010     27.39        89          40
# 2        pelabuhan klang   3.0000  101.4000     28.21        84         100
# 3                 bethel  41.3712  -73.4140     28.45        65          40
# 4                  utrik  11.2278  169.8474     28.27        78          14
#
#          Wind Speed Country        Date
# City_ID
# 0              5.55      RU  1693164541
# 1              3.09      MP  1693164541
# 2              1.59      MY  1693164541
# 3              3.60      US  1693164541
# 4              8.62      MH  1693164541

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df["Max Temp"]
plt.scatter(x_values, y_values,
                      edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel(" Max Temperature (C)")
plt.title("City Latitude vs. Max Tempature (2022-10-18)")
plt.grid()
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 13
#      11 plt.grid()
#      12 # Save the figure
# ---> 13 plt.savefig("../output_data/Fig1.png")
#      15 # Show plot
#      16 plt.show()
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:996, in savefig(*args, **kwargs)
#     993 @_copy_docstring_and_deprecators(Figure.savefig)
#     994 def savefig(*args, **kwargs):
#     995     fig = gcf()
# --> 996     res = fig.savefig(*args, **kwargs)
#     997     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     998     return res
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/figure.py:3328, in Figure.savefig(self, fname, transparent, **kwargs)
#    3324     for ax in self.axes:
#    3325         stack.enter_context(
#    3326             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3328 self.canvas.print_figure(fname, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py:2362, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2358 try:
#    2359     # _get_renderer may change the figure dpi (as vector formats
#    2360     # force the figure dpi to 72), so we need to set it again here.
#    2361     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2362         result = print_method(
#    2363             filename,
#    2364             facecolor=facecolor,
#    2365             edgecolor=edgecolor,
#    2366             orientation=orientation,
#    2367             bbox_inches_restore=_bbox_inches_restore,
#    2368             **kwargs)
#    2369 finally:
#    2370     if bbox_inches and restore_bbox:
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py:2228, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2224     optional_kws = {  # Passed by print_figure for other renderers.
#    2225         "dpi", "facecolor", "edgecolor", "orientation",
#    2226         "bbox_inches_restore"}
#    2227     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2228     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2229         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2230 else:  # Let third-parties do as they see fit.
#    2231     print_method = meth
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     462 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)
#     507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:458, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     453 """
#     454 Draw the canvas, then save it using `.image.imsave` (to which
#     455 *pil_kwargs* and *metadata* are forwarded).
#     456 """
#     457 FigureCanvasAgg.draw(self)
# --> 458 mpl.image.imsave(
#     459     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/image.py:1687, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1685 pil_kwargs.setdefault("format", format)
#    1686 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1687 image.save(fname, **pil_kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/PIL/Image.py:2428, in Image.save(self, fp, format, **params)
#    2426         fp = builtins.open(filename, "r+b")
#    2427     else:
# -> 2428         fp = builtins.open(filename, "w+b")
#    2430 try:
#    2431     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../output_data/Fig1.png'

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df["Humidity"]
plt.scatter(x_values, y_values,
                      edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2022-10-18)")
plt.grid()
# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 13
#      11 plt.grid()
#      12 # Save the figure
# ---> 13 plt.savefig("../output_data/Fig2.png")
#      15 # Show plot
#      16 plt.show()
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:996, in savefig(*args, **kwargs)
#     993 @_copy_docstring_and_deprecators(Figure.savefig)
#     994 def savefig(*args, **kwargs):
#     995     fig = gcf()
# --> 996     res = fig.savefig(*args, **kwargs)
#     997     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     998     return res
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/figure.py:3328, in Figure.savefig(self, fname, transparent, **kwargs)
#    3324     for ax in self.axes:
#    3325         stack.enter_context(
#    3326             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3328 self.canvas.print_figure(fname, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py:2362, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2358 try:
#    2359     # _get_renderer may change the figure dpi (as vector formats
#    2360     # force the figure dpi to 72), so we need to set it again here.
#    2361     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2362         result = print_method(
#    2363             filename,
#    2364             facecolor=facecolor,
#    2365             edgecolor=edgecolor,
#    2366             orientation=orientation,
#    2367             bbox_inches_restore=_bbox_inches_restore,
#    2368             **kwargs)
#    2369 finally:
#    2370     if bbox_inches and restore_bbox:
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py:2228, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2224     optional_kws = {  # Passed by print_figure for other renderers.
#    2225         "dpi", "facecolor", "edgecolor", "orientation",
#    2226         "bbox_inches_restore"}
#    2227     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2228     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2229         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2230 else:  # Let third-parties do as they see fit.
#    2231     print_method = meth
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     462 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)
#     507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:458, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     453 """
#     454 Draw the canvas, then save it using `.image.imsave` (to which
#     455 *pil_kwargs* and *metadata* are forwarded).
#     456 """
#     457 FigureCanvasAgg.draw(self)
# --> 458 mpl.image.imsave(
#     459     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/image.py:1687, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1685 pil_kwargs.setdefault("format", format)
#    1686 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1687 image.save(fname, **pil_kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/PIL/Image.py:2428, in Image.save(self, fp, format, **params)
#    2426         fp = builtins.open(filename, "r+b")
#    2427     else:
# -> 2428         fp = builtins.open(filename, "w+b")
#    2430 try:
#    2431     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../output_data/Fig2.png'

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df["Cloudiness"]
plt.scatter(x_values, y_values,
                      edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (2022-10-18)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 14
#      11 plt.grid()
#      13 # Save the figure
# ---> 14 plt.savefig("../output_data/Fig3.png")
#      16 # Show plot
#      17 plt.show()
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:996, in savefig(*args, **kwargs)
#     993 @_copy_docstring_and_deprecators(Figure.savefig)
#     994 def savefig(*args, **kwargs):
#     995     fig = gcf()
# --> 996     res = fig.savefig(*args, **kwargs)
#     997     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     998     return res
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/figure.py:3328, in Figure.savefig(self, fname, transparent, **kwargs)
#    3324     for ax in self.axes:
#    3325         stack.enter_context(
#    3326             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3328 self.canvas.print_figure(fname, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py:2362, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2358 try:
#    2359     # _get_renderer may change the figure dpi (as vector formats
#    2360     # force the figure dpi to 72), so we need to set it again here.
#    2361     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2362         result = print_method(
#    2363             filename,
#    2364             facecolor=facecolor,
#    2365             edgecolor=edgecolor,
#    2366             orientation=orientation,
#    2367             bbox_inches_restore=_bbox_inches_restore,
#    2368             **kwargs)
#    2369 finally:
#    2370     if bbox_inches and restore_bbox:
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py:2228, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2224     optional_kws = {  # Passed by print_figure for other renderers.
#    2225         "dpi", "facecolor", "edgecolor", "orientation",
#    2226         "bbox_inches_restore"}
#    2227     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2228     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2229         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2230 else:  # Let third-parties do as they see fit.
#    2231     print_method = meth
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     462 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)
#     507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:458, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     453 """
#     454 Draw the canvas, then save it using `.image.imsave` (to which
#     455 *pil_kwargs* and *metadata* are forwarded).
#     456 """
#     457 FigureCanvasAgg.draw(self)
# --> 458 mpl.image.imsave(
#     459     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/image.py:1687, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1685 pil_kwargs.setdefault("format", format)
#    1686 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1687 image.save(fname, **pil_kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/PIL/Image.py:2428, in Image.save(self, fp, format, **params)
#    2426         fp = builtins.open(filename, "r+b")
#    2427     else:
# -> 2428         fp = builtins.open(filename, "w+b")
#    2430 try:
#    2431     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../output_data/Fig3.png'

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df["Wind Speed"]
plt.scatter(x_values, y_values,
           edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed (2022-10-18)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 14
#      11 plt.grid()
#      13 # Save the figure
# ---> 14 plt.savefig("../output_data/Fig4.png")
#      16 # Show plot
#      17 plt.show()
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:996, in savefig(*args, **kwargs)
#     993 @_copy_docstring_and_deprecators(Figure.savefig)
#     994 def savefig(*args, **kwargs):
#     995     fig = gcf()
# --> 996     res = fig.savefig(*args, **kwargs)
#     997     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     998     return res
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/figure.py:3328, in Figure.savefig(self, fname, transparent, **kwargs)
#    3324     for ax in self.axes:
#    3325         stack.enter_context(
#    3326             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3328 self.canvas.print_figure(fname, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py:2362, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2358 try:
#    2359     # _get_renderer may change the figure dpi (as vector formats
#    2360     # force the figure dpi to 72), so we need to set it again here.
#    2361     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2362         result = print_method(
#    2363             filename,
#    2364             facecolor=facecolor,
#    2365             edgecolor=edgecolor,
#    2366             orientation=orientation,
#    2367             bbox_inches_restore=_bbox_inches_restore,
#    2368             **kwargs)
#    2369 finally:
#    2370     if bbox_inches and restore_bbox:
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py:2228, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2224     optional_kws = {  # Passed by print_figure for other renderers.
#    2225         "dpi", "facecolor", "edgecolor", "orientation",
#    2226         "bbox_inches_restore"}
#    2227     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2228     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2229         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2230 else:  # Let third-parties do as they see fit.
#    2231     print_method = meth
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     462 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)
#     507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:458, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     453 """
#     454 Draw the canvas, then save it using `.image.imsave` (to which
#     455 *pil_kwargs* and *metadata* are forwarded).
#     456 """
#     457 FigureCanvasAgg.draw(self)
# --> 458 mpl.image.imsave(
#     459     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/image.py:1687, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1685 pil_kwargs.setdefault("format", format)
#    1686 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1687 image.save(fname, **pil_kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/PIL/Image.py:2428, in Image.save(self, fp, format, **params)
#    2426         fp = builtins.open(filename, "r+b")
#    2427     else:
# -> 2428         fp = builtins.open(filename, "w+b")
#    2430 try:
#    2431     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../output_data/Fig4.png'

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, xlabel, ylabel):
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >=0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          vysokaya gora  55.9128   49.3017     10.10        90          65
# 1                 saipan  15.1355  145.7010     27.39        89          40
# 2        pelabuhan klang   3.0000  101.4000     28.21        84         100
# 3                 bethel  41.3712  -73.4140     28.45        65          40
# 4                  utrik  11.2278  169.8474     28.27        78          14
#
#          Wind Speed Country        Date
# City_ID
# 0              5.55      RU  1693164541
# 1              3.09      MP  1693164541
# 2              1.59      MY  1693164541
# 3              3.60      US  1693164541
# 4              8.62      MH  1693164541

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 5             bahia blanca -38.7196  -62.2724     16.57        18           0
# 6                 tolanaro -25.0319   46.9987     22.04        78          75
# 8        port-aux-francais -49.3500   70.2167      6.37        96         100
# 10            puerto ayora  -0.7393  -90.3518     29.98        82          98
# 11          margaret river -33.9500  115.0667     15.18        86          72
#
#          Wind Speed Country        Date
# City_ID
# 5              4.47      AR  1693164542
# 6              5.14      MG  1693164542
# 8             18.48      TF  1693164542
# 10             3.13      EC  1693164543
# 11             3.38      AU  1693164543

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
## Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (0,0), color="red")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.5256848039602119

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-50,30), color="red")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7408644492534154

# %% [markdown]
# **Discussion about the linear relationship:** The higher the latitude the higher the temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (50,10), color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.013086065017005589

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-50,30), color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.021237439231580654

# %% [markdown]
# **Discussion about the linear relationship:** The higher the latitude the lower the humidity

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (60,10), color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 7.17886162175453e-06

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** The higher the latitude the highr the cloudiness

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (10,12), color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.012928087732191333

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-50,14), color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00505896818903211

# %% [markdown]
# **Discussion about the linear relationship:** There doesn't seem to be a significant relationship between the two. It seems pretty constant.
